# %%
import pandas as pd

df=pd.read_csv("C:\\Users\\hari_\\Python notebooks\\datafiles\\airbnb1.csv")
df
# Out:
#        room_id   host_id        room_type  borough  neighborhood  reviews  \
# 0      7880823  41542517  Entire home/apt      NaN            24        0
# 1     15322528  97637165  Entire home/apt      NaN            24        1
# 2      6920908  36273927  Entire home/apt      NaN            24        1
# 3      3249155  11206742  Entire home/apt      NaN            24        5
# 4      1242948   6193751     Private room      NaN            24        1
# 5      8572129  44932890     Private room      NaN             1        4
# 6     11606479  61426999  Entire home/apt      NaN            24        5
# 7      9359600  48570226     Private room      NaN            24       16
# 8     15477304  65071273     Private room      NaN             4        0
# 9      7877104  41273215     Private room      NaN             6        1
# 10    13589545  18333196     Private room      NaN             4        2
# 11    11525016   3756437  Entire home/apt      NaN             4        3
# ...

# %%
df.columns
# Out:
# Index(['room_id', 'host_id', 'room_type', 'borough', 'neighborhood', 'reviews',
#        'overall_satisfaction', 'accommodates', 'bedrooms', 'price', 'minstay',
#        'latitude', 'longitude', 'last_modified'],
#       dtype='object')

# %%
df.dtypes
# Out:
# room_id                   int64
# host_id                   int64
# room_type                object
# borough                 float64
# neighborhood              int64
# reviews                   int64
# overall_satisfaction    float64
# accommodates              int64
# bedrooms                float64
# price                     int64
# minstay                 float64
# latitude                float64
# longitude               float64
# last_modified            object
# dtype: object

# %%
df.head(10)
# Out:
#     room_id   host_id        room_type  borough  neighborhood  reviews  \
# 0   7880823  41542517  Entire home/apt      NaN            24        0
# 1  15322528  97637165  Entire home/apt      NaN            24        1
# 2   6920908  36273927  Entire home/apt      NaN            24        1
# 3   3249155  11206742  Entire home/apt      NaN            24        5
# 4   1242948   6193751     Private room      NaN            24        1
# 5   8572129  44932890     Private room      NaN             1        4
# 6  11606479  61426999  Entire home/apt      NaN            24        5
# 7   9359600  48570226     Private room      NaN            24       16
# 8  15477304  65071273     Private room      NaN             4        0
# 9   7877104  41273215     Private room      NaN             6        1
#
#    overall_satisfaction  accommodates  bedrooms  price  minstay   latitude  \
# 0                   NaN             2       1.0     68      1.0  56.164097
# ...

# %%
df.tail(10)
# Out:
#        room_id   host_id     room_type  borough  neighborhood  reviews  \
# 2248  15533310  99911628  Private room      NaN            24        1
# 2249  10427411  53685813  Private room      NaN            24       56
# 2250   7566529  22372811  Private room      NaN             4       10
# 2251  13713859  10805331  Private room      NaN             1       13
# 2252  15247646  38670225  Private room      NaN             3        5
# 2253  13955327  51321031  Private room      NaN            24       10
# 2254  12977847  58380304  Private room      NaN             3       26
# 2255  13588809  48570226  Private room      NaN            24        8
# 2256   4087394  16674431  Private room      NaN             4       71
# 2257  12062157  11329263  Private room      NaN             4       33
#
#       overall_satisfaction  accommodates  bedrooms  price  minstay   latitude  \
# 2248                   NaN             1       1.0     27      1.0  56.146439
# ...

# %%
df.describe()
# Out:
#             room_id       host_id  borough  neighborhood      reviews  \
# count  2.258000e+03  2.258000e+03      0.0   2258.000000  2258.000000
# mean   9.397950e+06  3.617710e+07      NaN     17.365368     5.550930
# std    4.290220e+06  2.542905e+07      NaN      9.391867    10.035662
# min    6.010800e+04  1.188230e+05      NaN      1.000000     0.000000
# 25%    6.321060e+06  1.526136e+07      NaN      5.000000     0.000000
# 50%    9.765390e+06  3.260494e+07      NaN     24.000000     2.000000
# 75%    1.341276e+07  5.330016e+07      NaN     24.000000     6.000000
# max    1.573285e+07  1.011867e+08      NaN     24.000000   117.000000
#
#        overall_satisfaction  accommodates     bedrooms        price  \
# count           1001.000000   2258.000000  2255.000000  2258.000000
# mean               4.709291      3.254207     1.480710    79.872896
# std                0.319223      1.634812     0.856343   207.441930
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2258, step=1)

# %%
exc= pd.read_excel("C:\\Users\\hari_\\Python notebooks\\datafiles\\Module2 - Lab1.xls")

# %%
df =pd.read_csv("C:\\Users\\hari_\\Python notebooks\\edx\\Module2\\Datasets\\direct_marketing.csv")

# %%
df.head(5)
# Out:
#    recency history_segment  history  mens  womens   zip_code  newbie channel  \
# 0       10  2) $100 - $200   142.44     1       0  Surburban       0   Phone
# 1        6  3) $200 - $350   329.08     1       1      Rural       1     Web
# 2        7  2) $100 - $200   180.65     0       1  Surburban       1     Web
# 3        9  5) $500 - $750   675.83     1       0      Rural       1     Web
# 4        2    1) $0 - $100    45.34     1       0      Urban       0     Web
#
#          segment  visit  conversion  spend  DM_category
# 0  Womens E-Mail      0           0    0.0            4
# 1      No E-Mail      0           0    0.0           11
# 2  Womens E-Mail      0           0    0.0            1
# 3    Mens E-Mail      0           0    0.0            2
# 4  Womens E-Mail      0           0    0.0            4

# %%
df.loc[0:2,['history']]
# Out:
#    history
# 0   142.44
# 1   329.08
# 2   180.65

# %%
df.iloc[0:10,0:4]
# Out:
#    recency history_segment  history  mens
# 0       10  2) $100 - $200   142.44     1
# 1        6  3) $200 - $350   329.08     1
# 2        7  2) $100 - $200   180.65     0
# 3        9  5) $500 - $750   675.83     1
# 4        2    1) $0 - $100    45.34     1
# 5        6  2) $100 - $200   134.83     0
# 6        9  3) $200 - $350   280.20     1
# 7        9    1) $0 - $100    46.42     0
# 8        9  5) $500 - $750   675.07     1
# 9       10    1) $0 - $100    32.84     0

# %%
sel1 = df.recency < 7
sel2 = df.mens == 0
sel3 = df.history < 100
sel4 = df.channel == 'Phone'
#df[sel & sel2 & sel3 & sel4 ]

# %%
newseries =['sad', 'verysad','neutral','happy','veryhappy']
ndf = pd.DataFrame({'satisfaction':['veryhappy','happy','neutral','mad','verysad']})
ndf ['satisfaction2'] = ndf.satisfaction.astype(dtype='category',ordered=True, categories=newseries)
ndf
# Out:
# c:\users\hari_\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#   satisfaction satisfaction2
# 0    veryhappy     veryhappy
# 1        happy         happy
# 2      neutral       neutral
# 3          mad           NaN
# 4      verysad       verysad

# %%
ndf.satisfaction2 = ndf.satisfaction2.cat.codes
ndf.satisfaction2
# Out:
# 0    4
# 1    3
# 2    2
# 3   -1
# 4    1
# Name: satisfaction2, dtype: int8

# %%
ndf1 = pd.DataFrame({'vetebrates':['Bird','Fish','Mamamal','Reptile','Amphbian','Bird','Fish','Mamamal']})
ndf1['vetebrates2'] = ndf1.vetebrates.astype("category").cat.codes
ndf1 = pd.get_dummies(ndf1,columns=['vetebrates'])
ndf1
# Out:
#    vetebrates2  vetebrates_Amphbian  vetebrates_Bird  vetebrates_Fish  \
# 0            1                    0                1                0
# 1            2                    0                0                1
# 2            3                    0                0                0
# 3            4                    0                0                0
# 4            0                    1                0                0
# 5            1                    0                1                0
# 6            2                    0                0                1
# 7            3                    0                0                0
#
#    vetebrates_Mamamal  vetebrates_Reptile
# 0                   0                   0
# 1                   0                   0
# 2                   1                   0
# 3                   0                   1
# 4                   0                   0
# 5                   0                   0
# ...

# %%
df
# Out:
#        room_id   host_id        room_type  borough  neighborhood  reviews  \
# 0      7880823  41542517  Entire home/apt      NaN            24        0
# 1     15322528  97637165  Entire home/apt      NaN            24        1
# 2      6920908  36273927  Entire home/apt      NaN            24        1
# 3      3249155  11206742  Entire home/apt      NaN            24        5
# 4      1242948   6193751     Private room      NaN            24        1
# 5      8572129  44932890     Private room      NaN             1        4
# 6     11606479  61426999  Entire home/apt      NaN            24        5
# 7      9359600  48570226     Private room      NaN            24       16
# 8     15477304  65071273     Private room      NaN             4        0
# 9      7877104  41273215     Private room      NaN             6        1
# 10    13589545  18333196     Private room      NaN             4        2
# 11    11525016   3756437  Entire home/apt      NaN             4        3
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
matplotlib.style.use('ggplot')

# %%
df[df.bedrooms==1.0].minstay.plot.hist(title="minimum stay", bins=6)
df[df.bedrooms==2.0].minstay.plot.hist(title="minimum stay", bins=6)
df[df.bedrooms==3.0].minstay.plot.hist(title="minimum stay", bins=6)
plt.show()

# %%
df=pd.read_csv("C:\\Users\\hari_\\Python notebooks\\edx\\Module3\\Datasets\\students.data")

# %%
df.columns
# Out:
# Index(['id', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id            int64
# sex           int64
# age           int64
# address       int64
# famsize       int64
# Pstatus       int64
# Medu          int64
# Fedu          int64
# traveltime    int64
# studytime     int64
# failures      int64
# schoolsup     int64
# famsup        int64
# paid          int64
# activities    int64
# nursery       int64
# higher        int64
# internet      int64
# romantic      int64
# famrel        int64
# freetime      int64
# goout         int64
# Dalc          int64
# Walc          int64
# health        int64
# absences      int64
# G1            int64
# G2            int64
# G3            int64
# dtype: object

# %%
my_series = df.G3
my_dataframe= df[['G3','G2','G1']]
my_series.plot.hist(title="G3", bins=5)
my_dataframe.plot.hist(title="D", bins=5)
plt.show()
